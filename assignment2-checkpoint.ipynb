# %%
#import the libraries
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException
import os
import shutil
import requests

#getting the url of webpage

driver=webdriver.Chrome("D:\\chromedriver_win32\\chromedriver.exe")
my_page=driver.get('https://www.amazon.in/gp/browse.html?node=1968093031&ref_=nav_em_sbc_mfashion_shirts_0_2_9_4')

# %%
#make directory to store scrapped images

def make_directory(dirname):
    current_path=os.getcwd()
    path=os.path.join(current_path,dirname)
    if not os.path.exists(path):
        os.makedirs(path)

# %%
make_directory('Amazon')

# %%
#scraping images of further pages

start_page=1
total_pages=3

def scrap_image_url(driver):
    images=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-base']//img")
    product_data= {}
    product_data['image_urls']=[]
    for image in images:
        source=image.get_attribute('src')
        product_data['image_urls'].append(source)
    return product_data


def save_images(data,dirname,page):
    for index,link in enumerate(data['image_urls']):
        print('Downloading {0} of {1} images'.format(index+1,len(data['image_urls'])))
        response=requests.get(link)
        with open('{0}/img_{1}{2}.jpeg'.format(dirname,page,index),'wb') as file:
            file.write(response.content)

# %%
for page in range(start_page, total_pages+1):
    try:
        product=scrap_image_url(driver=driver)
        print("Scraping page {0} of {1} pages".format(page,total_pages))
         
        page_value=driver.find_element_by_xpath("//span[@class='pagnLink']//a").text
        print('The Current Page Scrapped is {}'.format(page_value))
        
        #download the images
        save_images(data=product,dirname='Amazon',page=page)
        print("Scraping of page {0} done".format(page))
        
    except StaleElementReferenceException as Exception:
        print('We are facing an exception')
        
        exp_page=driver.find_element_by_xpath("//span[@class='pagnLink']//a").text
        print('The page value at the time of exception is {}'.format(exp_page))
        
        value=driver.find_element_by_xpath("//span[@class='pagnLink']//a")
        link=value.get_attribute('href')
        driver.get(link)
        
        product=scrap_image_url(driver=driver)
        print("Scraping page {0} of {1} pages".format(page,total_pages))
         
        page_value=driver.find_element_by_xpath("//span[@class='pagnLink']//a").text
        print('The Current Page Scrapped is {}'.format(page_value))
        
        #download the images
        save_images(data=product,dirname='Amazon',page=page)
        print("Scraping of page {0} done".format(page))
# Out:
# Scraping page 1 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 51 images
# Downloading 2 of 51 images
# Downloading 3 of 51 images
# Downloading 4 of 51 images
# Downloading 5 of 51 images
# Downloading 6 of 51 images
# Downloading 7 of 51 images
# Downloading 8 of 51 images
# Downloading 9 of 51 images
# Downloading 10 of 51 images
# Downloading 11 of 51 images
# Downloading 12 of 51 images
# Downloading 13 of 51 images
# Downloading 14 of 51 images
# Downloading 15 of 51 images
# Downloading 16 of 51 images
# Downloading 17 of 51 images
# Downloading 18 of 51 images
# Downloading 19 of 51 images
# Downloading 20 of 51 images
# Downloading 21 of 51 images
# Downloading 22 of 51 images
# Downloading 23 of 51 images
# Downloading 24 of 51 images
# Downloading 25 of 51 images
# Downloading 26 of 51 images
# Downloading 27 of 51 images
# Downloading 28 of 51 images
# Downloading 29 of 51 images
# Downloading 30 of 51 images
# Downloading 31 of 51 images
# Downloading 32 of 51 images
# Downloading 33 of 51 images
# Downloading 34 of 51 images
# Downloading 35 of 51 images
# Downloading 36 of 51 images
# Downloading 37 of 51 images
# Downloading 38 of 51 images
# Downloading 39 of 51 images
# Downloading 40 of 51 images
# Downloading 41 of 51 images
# Downloading 42 of 51 images
# Downloading 43 of 51 images
# Downloading 44 of 51 images
# Downloading 45 of 51 images
# Downloading 46 of 51 images
# Downloading 47 of 51 images
# Downloading 48 of 51 images
# Downloading 49 of 51 images
# Downloading 50 of 51 images
# Downloading 51 of 51 images
# Scraping of page 1 done
# Scraping page 2 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 51 images
# Downloading 2 of 51 images
# Downloading 3 of 51 images
# Downloading 4 of 51 images
# Downloading 5 of 51 images
# Downloading 6 of 51 images
# Downloading 7 of 51 images
# Downloading 8 of 51 images
# Downloading 9 of 51 images
# Downloading 10 of 51 images
# Downloading 11 of 51 images
# Downloading 12 of 51 images
# Downloading 13 of 51 images
# Downloading 14 of 51 images
# Downloading 15 of 51 images
# Downloading 16 of 51 images
# Downloading 17 of 51 images
# Downloading 18 of 51 images
# Downloading 19 of 51 images
# Downloading 20 of 51 images
# Downloading 21 of 51 images
# Downloading 22 of 51 images
# Downloading 23 of 51 images
# Downloading 24 of 51 images
# Downloading 25 of 51 images
# Downloading 26 of 51 images
# Downloading 27 of 51 images
# Downloading 28 of 51 images
# Downloading 29 of 51 images
# Downloading 30 of 51 images
# Downloading 31 of 51 images
# Downloading 32 of 51 images
# Downloading 33 of 51 images
# Downloading 34 of 51 images
# Downloading 35 of 51 images
# Downloading 36 of 51 images
# Downloading 37 of 51 images
# Downloading 38 of 51 images
# Downloading 39 of 51 images
# Downloading 40 of 51 images
# Downloading 41 of 51 images
# Downloading 42 of 51 images
# Downloading 43 of 51 images
# Downloading 44 of 51 images
# Downloading 45 of 51 images
# Downloading 46 of 51 images
# Downloading 47 of 51 images
# Downloading 48 of 51 images
# Downloading 49 of 51 images
# Downloading 50 of 51 images
# Downloading 51 of 51 images
# Scraping of page 2 done
# Scraping page 3 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 51 images
# Downloading 2 of 51 images
# Downloading 3 of 51 images
# Downloading 4 of 51 images
# Downloading 5 of 51 images
# Downloading 6 of 51 images
# Downloading 7 of 51 images
# Downloading 8 of 51 images
# Downloading 9 of 51 images
# Downloading 10 of 51 images
# Downloading 11 of 51 images
# Downloading 12 of 51 images
# Downloading 13 of 51 images
# Downloading 14 of 51 images
# Downloading 15 of 51 images
# Downloading 16 of 51 images
# Downloading 17 of 51 images
# Downloading 18 of 51 images
# Downloading 19 of 51 images
# Downloading 20 of 51 images
# Downloading 21 of 51 images
# Downloading 22 of 51 images
# Downloading 23 of 51 images
# Downloading 24 of 51 images
# Downloading 25 of 51 images
# Downloading 26 of 51 images
# Downloading 27 of 51 images
# Downloading 28 of 51 images
# Downloading 29 of 51 images
# Downloading 30 of 51 images
# Downloading 31 of 51 images
# Downloading 32 of 51 images
# Downloading 33 of 51 images
# Downloading 34 of 51 images
# Downloading 35 of 51 images
# Downloading 36 of 51 images
# Downloading 37 of 51 images
# Downloading 38 of 51 images
# Downloading 39 of 51 images
# Downloading 40 of 51 images
# Downloading 41 of 51 images
# Downloading 42 of 51 images
# Downloading 43 of 51 images
# Downloading 44 of 51 images
# Downloading 45 of 51 images
# Downloading 46 of 51 images
# Downloading 47 of 51 images
# Downloading 48 of 51 images
# Downloading 49 of 51 images
# Downloading 50 of 51 images
# Downloading 51 of 51 images
# Scraping of page 3 done

# %%
#import the libraries

from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException
import os
import shutil
import requests

#getting the url of webpage

driver=webdriver.Chrome('D:\\chromedriver_win32\\chromedriver.exe')
my_page=driver.get('https://www.amazon.in/gp/browse.html?node=1968120031&ref_=nav_em_sbc_mfashion_tshirts_0_2_9_3')

# %%
#make directory to store scrapped images

def make_directory(dirname):
    current_path=os.getcwd()
    path=os.path.join(current_path,dirname)
    if not os.path.exists(path):
        os.makedirs(path)

# %%
make_directory('Amazon_men_Tshirts')

# %%
#scraping images of further pages

start_page=1
total_pages=3

def scrap_image_url(driver):
    images=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']//img")
    product_data= {}
    product_data['image_urls']=[]
    for image in images:
        source=image.get_attribute('src')
        product_data['image_urls'].append(source)
    return product_data


def save_images(data,dirname,page):
    for index,link in enumerate(data['image_urls']):
        print('Downloading {0} of {1} images'.format(index+1,len(data['image_urls'])))
        response=requests.get(link)
        with open('{0}/img_{1}{2}.jpeg'.format(dirname,page,index),'wb') as file:
            file.write(response.content)

# %%
for page in range(start_page, total_pages+1):
    try:
        product=scrap_image_url(driver=driver)
        print("Scraping page {0} of {1} pages".format(page,total_pages))
         
        page_value=driver.find_element_by_xpath("//li[@class='a-normal']//a").text
        print('The Current Page Scrapped is {}'.format(page_value))
        
        #download the images
        save_images(data=product,dirname='Amazon_men_Tshirts',page=page)
        print("Scraping of page {0} done".format(page))
        
    except StaleElementReferenceException as Exception:
        print('We are facing an exception')
        
        exp_page=driver.find_element_by_xpath("//li[@class='a-normal']//a").text
        print('The page value at the time of exception is {}'.format(exp_page))
        
        value=driver.find_element_by_xpath("//li[@class='a-normal']//a")
        link=value.get_attribute('href')
        driver.get(link)
        
        product=scrap_image_url(driver=driver)
        print("Scraping page {0} of {1} pages".format(page,total_pages))
         
        page_value=driver.find_element_by_xpath("//li[@class='a-normal']//a").text
        print('The Current Page Scrapped is {}'.format(page_value))
        
        #download the images
        save_images(data=product,dirname='Amazon_men_Tshirts',page=page)
        print("Scraping of page {0} done".format(page))
# Out:
# Scraping page 1 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 60 images
# Downloading 2 of 60 images
# Downloading 3 of 60 images
# Downloading 4 of 60 images
# Downloading 5 of 60 images
# Downloading 6 of 60 images
# Downloading 7 of 60 images
# Downloading 8 of 60 images
# Downloading 9 of 60 images
# Downloading 10 of 60 images
# Downloading 11 of 60 images
# Downloading 12 of 60 images
# Downloading 13 of 60 images
# Downloading 14 of 60 images
# Downloading 15 of 60 images
# Downloading 16 of 60 images
# Downloading 17 of 60 images
# Downloading 18 of 60 images
# Downloading 19 of 60 images
# Downloading 20 of 60 images
# Downloading 21 of 60 images
# Downloading 22 of 60 images
# Downloading 23 of 60 images
# Downloading 24 of 60 images
# Downloading 25 of 60 images
# Downloading 26 of 60 images
# Downloading 27 of 60 images
# Downloading 28 of 60 images
# Downloading 29 of 60 images
# Downloading 30 of 60 images
# Downloading 31 of 60 images
# Downloading 32 of 60 images
# Downloading 33 of 60 images
# Downloading 34 of 60 images
# Downloading 35 of 60 images
# Downloading 36 of 60 images
# Downloading 37 of 60 images
# Downloading 38 of 60 images
# Downloading 39 of 60 images
# Downloading 40 of 60 images
# Downloading 41 of 60 images
# Downloading 42 of 60 images
# Downloading 43 of 60 images
# Downloading 44 of 60 images
# Downloading 45 of 60 images
# Downloading 46 of 60 images
# Downloading 47 of 60 images
# Downloading 48 of 60 images
# Downloading 49 of 60 images
# Downloading 50 of 60 images
# Downloading 51 of 60 images
# Downloading 52 of 60 images
# Downloading 53 of 60 images
# Downloading 54 of 60 images
# Downloading 55 of 60 images
# Downloading 56 of 60 images
# Downloading 57 of 60 images
# Downloading 58 of 60 images
# Downloading 59 of 60 images
# Downloading 60 of 60 images
# Scraping of page 1 done
# Scraping page 2 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 60 images
# Downloading 2 of 60 images
# Downloading 3 of 60 images
# Downloading 4 of 60 images
# Downloading 5 of 60 images
# Downloading 6 of 60 images
# Downloading 7 of 60 images
# Downloading 8 of 60 images
# Downloading 9 of 60 images
# Downloading 10 of 60 images
# Downloading 11 of 60 images
# Downloading 12 of 60 images
# Downloading 13 of 60 images
# Downloading 14 of 60 images
# Downloading 15 of 60 images
# Downloading 16 of 60 images
# Downloading 17 of 60 images
# Downloading 18 of 60 images
# Downloading 19 of 60 images
# Downloading 20 of 60 images
# Downloading 21 of 60 images
# Downloading 22 of 60 images
# Downloading 23 of 60 images
# Downloading 24 of 60 images
# Downloading 25 of 60 images
# Downloading 26 of 60 images
# Downloading 27 of 60 images
# Downloading 28 of 60 images
# Downloading 29 of 60 images
# Downloading 30 of 60 images
# Downloading 31 of 60 images
# Downloading 32 of 60 images
# Downloading 33 of 60 images
# Downloading 34 of 60 images
# Downloading 35 of 60 images
# Downloading 36 of 60 images
# Downloading 37 of 60 images
# Downloading 38 of 60 images
# Downloading 39 of 60 images
# Downloading 40 of 60 images
# Downloading 41 of 60 images
# Downloading 42 of 60 images
# Downloading 43 of 60 images
# Downloading 44 of 60 images
# Downloading 45 of 60 images
# Downloading 46 of 60 images
# Downloading 47 of 60 images
# Downloading 48 of 60 images
# Downloading 49 of 60 images
# Downloading 50 of 60 images
# Downloading 51 of 60 images
# Downloading 52 of 60 images
# Downloading 53 of 60 images
# Downloading 54 of 60 images
# Downloading 55 of 60 images
# Downloading 56 of 60 images
# Downloading 57 of 60 images
# Downloading 58 of 60 images
# Downloading 59 of 60 images
# Downloading 60 of 60 images
# Scraping of page 2 done
# Scraping page 3 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 60 images
# Downloading 2 of 60 images
# Downloading 3 of 60 images
# Downloading 4 of 60 images
# Downloading 5 of 60 images
# Downloading 6 of 60 images
# Downloading 7 of 60 images
# Downloading 8 of 60 images
# Downloading 9 of 60 images
# Downloading 10 of 60 images
# Downloading 11 of 60 images
# Downloading 12 of 60 images
# Downloading 13 of 60 images
# Downloading 14 of 60 images
# Downloading 15 of 60 images
# Downloading 16 of 60 images
# Downloading 17 of 60 images
# Downloading 18 of 60 images
# Downloading 19 of 60 images
# Downloading 20 of 60 images
# Downloading 21 of 60 images
# Downloading 22 of 60 images
# Downloading 23 of 60 images
# Downloading 24 of 60 images
# Downloading 25 of 60 images
# Downloading 26 of 60 images
# Downloading 27 of 60 images
# Downloading 28 of 60 images
# Downloading 29 of 60 images
# Downloading 30 of 60 images
# Downloading 31 of 60 images
# Downloading 32 of 60 images
# Downloading 33 of 60 images
# Downloading 34 of 60 images
# Downloading 35 of 60 images
# Downloading 36 of 60 images
# Downloading 37 of 60 images
# Downloading 38 of 60 images
# Downloading 39 of 60 images
# Downloading 40 of 60 images
# Downloading 41 of 60 images
# Downloading 42 of 60 images
# Downloading 43 of 60 images
# Downloading 44 of 60 images
# Downloading 45 of 60 images
# Downloading 46 of 60 images
# Downloading 47 of 60 images
# Downloading 48 of 60 images
# Downloading 49 of 60 images
# Downloading 50 of 60 images
# Downloading 51 of 60 images
# Downloading 52 of 60 images
# Downloading 53 of 60 images
# Downloading 54 of 60 images
# Downloading 55 of 60 images
# Downloading 56 of 60 images
# Downloading 57 of 60 images
# Downloading 58 of 60 images
# Downloading 59 of 60 images
# Downloading 60 of 60 images
# Scraping of page 3 done

# %%
#import the libraries

from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException
import os
import shutil
import requests

#getting the url of webpage

driver=webdriver.Chrome("D:\\chromedriver_win32\\chromedriver.exe")
my_page=driver.get('https://www.amazon.in/s/ref=lp_1968253031_nr_n_0?fst=as%3Aoff&rh=n%3A1571271031%2Cn%3A%211571272031%2Cn%3A1953602031%2Cn%3A1968253031%2Cn%3A1968256031&bbn=1968253031&ie=UTF8&qid=1593952433&rnid=1968253031')

# %%
#make directory to store scrapped images

def make_directory(dirname):
    current_path=os.getcwd()
    path=os.path.join(current_path,dirname)
    if not os.path.exists(path):
        os.makedirs(path)

# %%
make_directory('Amazon_women_sarees')

# %%
#scraping images of further pages

start_page=1
total_pages=3

def scrap_image_url(driver):
    images=driver.find_elements_by_xpath("//div[@class='a-row a-gesture a-gesture-horizontal']//img")
    product_data= {}
    product_data['image_urls']=[]
    for image in images:
        source=image.get_attribute('src')
        product_data['image_urls'].append(source)
    return product_data


def save_images(data,dirname,page):
    for index,link in enumerate(data['image_urls']):
        print('Downloading {0} of {1} images'.format(index+1,len(data['image_urls'])))
        response=requests.get(link)
        with open('{0}/img_{1}{2}.jpeg'.format(dirname,page,index),'wb') as file:
            file.write(response.content)

# %%
for page in range(start_page, total_pages+1):
    try:
        product=scrap_image_url(driver=driver)
        print("Scraping page {0} of {1} pages".format(page,total_pages))
         
        page_value=driver.find_element_by_xpath("//span[@class='pagnLink']//a").text
        print('The Current Page Scrapped is {}'.format(page_value))
        
        #download the images
        save_images(data=product,dirname='Amazon_women_sarees',page=page)
        print("Scraping of page {0} done".format(page))
        
    except StaleElementReferenceException as Exception:
        print('We are facing an exception')
        
        exp_page=driver.find_element_by_xpath("//span[@class='pagnLink']//a").text
        print('The page value at the time of exception is {}'.format(exp_page))
        
        value=driver.find_element_by_xpath("//span[@class='pagnLink']//a")
        link=value.get_attribute('href')
        driver.get(link)
        
        product=scrap_image_url(driver=driver)
        print("Scraping page {0} of {1} pages".format(page,total_pages))
         
        page_value=driver.find_element_by_xpath("//span[@class='pagnLink']//a").text
        print('The Current Page Scrapped is {}'.format(page_value))
        
        #download the images
        save_images(data=product,dirname='Amazon_women_sarees',page=page)
        print("Scraping of page {0} done".format(page))
# Out:
# Scraping page 1 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 46 images
# Downloading 2 of 46 images
# Downloading 3 of 46 images
# Downloading 4 of 46 images
# Downloading 5 of 46 images
# Downloading 6 of 46 images
# Downloading 7 of 46 images
# Downloading 8 of 46 images
# Downloading 9 of 46 images
# Downloading 10 of 46 images
# Downloading 11 of 46 images
# Downloading 12 of 46 images
# Downloading 13 of 46 images
# Downloading 14 of 46 images
# Downloading 15 of 46 images
# Downloading 16 of 46 images
# Downloading 17 of 46 images
# Downloading 18 of 46 images
# Downloading 19 of 46 images
# Downloading 20 of 46 images
# Downloading 21 of 46 images
# Downloading 22 of 46 images
# Downloading 23 of 46 images
# Downloading 24 of 46 images
# Downloading 25 of 46 images
# Downloading 26 of 46 images
# Downloading 27 of 46 images
# Downloading 28 of 46 images
# Downloading 29 of 46 images
# Downloading 30 of 46 images
# Downloading 31 of 46 images
# Downloading 32 of 46 images
# Downloading 33 of 46 images
# Downloading 34 of 46 images
# Downloading 35 of 46 images
# Downloading 36 of 46 images
# Downloading 37 of 46 images
# Downloading 38 of 46 images
# Downloading 39 of 46 images
# Downloading 40 of 46 images
# Downloading 41 of 46 images
# Downloading 42 of 46 images
# Downloading 43 of 46 images
# Downloading 44 of 46 images
# Downloading 45 of 46 images
# Downloading 46 of 46 images
# Scraping of page 1 done
# Scraping page 2 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 46 images
# Downloading 2 of 46 images
# Downloading 3 of 46 images
# Downloading 4 of 46 images
# Downloading 5 of 46 images
# Downloading 6 of 46 images
# Downloading 7 of 46 images
# Downloading 8 of 46 images
# Downloading 9 of 46 images
# Downloading 10 of 46 images
# Downloading 11 of 46 images
# Downloading 12 of 46 images
# Downloading 13 of 46 images
# Downloading 14 of 46 images
# Downloading 15 of 46 images
# Downloading 16 of 46 images
# Downloading 17 of 46 images
# Downloading 18 of 46 images
# Downloading 19 of 46 images
# Downloading 20 of 46 images
# Downloading 21 of 46 images
# Downloading 22 of 46 images
# Downloading 23 of 46 images
# Downloading 24 of 46 images
# Downloading 25 of 46 images
# Downloading 26 of 46 images
# Downloading 27 of 46 images
# Downloading 28 of 46 images
# Downloading 29 of 46 images
# Downloading 30 of 46 images
# Downloading 31 of 46 images
# Downloading 32 of 46 images
# Downloading 33 of 46 images
# Downloading 34 of 46 images
# Downloading 35 of 46 images
# Downloading 36 of 46 images
# Downloading 37 of 46 images
# Downloading 38 of 46 images
# Downloading 39 of 46 images
# Downloading 40 of 46 images
# Downloading 41 of 46 images
# Downloading 42 of 46 images
# Downloading 43 of 46 images
# Downloading 44 of 46 images
# Downloading 45 of 46 images
# Downloading 46 of 46 images
# Scraping of page 2 done
# Scraping page 3 of 3 pages
# The Current Page Scrapped is 2
# Downloading 1 of 46 images
# Downloading 2 of 46 images
# Downloading 3 of 46 images
# Downloading 4 of 46 images
# Downloading 5 of 46 images
# Downloading 6 of 46 images
# Downloading 7 of 46 images
# Downloading 8 of 46 images
# Downloading 9 of 46 images
# Downloading 10 of 46 images
# Downloading 11 of 46 images
# Downloading 12 of 46 images
# Downloading 13 of 46 images
# Downloading 14 of 46 images
# Downloading 15 of 46 images
# Downloading 16 of 46 images
# Downloading 17 of 46 images
# Downloading 18 of 46 images
# Downloading 19 of 46 images
# Downloading 20 of 46 images
# Downloading 21 of 46 images
# Downloading 22 of 46 images
# Downloading 23 of 46 images
# Downloading 24 of 46 images
# Downloading 25 of 46 images
# Downloading 26 of 46 images
# Downloading 27 of 46 images
# Downloading 28 of 46 images
# Downloading 29 of 46 images
# Downloading 30 of 46 images
# Downloading 31 of 46 images
# Downloading 32 of 46 images
# Downloading 33 of 46 images
# Downloading 34 of 46 images
# Downloading 35 of 46 images
# Downloading 36 of 46 images
# Downloading 37 of 46 images
# Downloading 38 of 46 images
# Downloading 39 of 46 images
# Downloading 40 of 46 images
# Downloading 41 of 46 images
# Downloading 42 of 46 images
# Downloading 43 of 46 images
# Downloading 44 of 46 images
# Downloading 45 of 46 images
# Downloading 46 of 46 images
# Scraping of page 3 done

# %%
#importing the libraries

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,Conv2D,MaxPooling2D
from keras.utils import np_utils
from keras import optimizers
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\mt110\anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:17: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
input_shape=(128,128,3)
img_width=128
img_height=128

train_samples=316
validation_samples=122
batch_size=32
epochs=10

train_data_dir="C:\\Users\\mt110\\data1\\Train"
validation_data_dir="C:\\Users\\mt110\\data1\\Validation"

#used to rescale the pixel values to (0,1) interval
image_data_generator=ImageDataGenerator(rescale=1./255)

# %%
#automatically retrieve images and their classes for both train and test dataset
train_generator=image_data_generator.flow_from_directory(
        train_data_dir,
        target_size=(img_width,img_height),
        batch_size=16)

validation_generator=image_data_generator.flow_from_directory(
        validation_data_dir,
        target_size=(img_width,img_height),
        batch_size=16)
# Out:
# Found 465 images belonging to 3 classes.
# Found 465 images belonging to 3 classes.

# %%
model=Sequential()

model.add(Conv2D(32,(3,3),input_shape=input_shape,activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
    
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
    
print(model.summary())
  
model.compile(optimizer='adam',metrics=['accuracy'],loss='categorical_crossentropy')
# Out:
# WARNING:tensorflow:From C:\Users\mt110\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1605760
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,634,787
# Trainable params: 1,634,787
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history=model.fit_generator(
            train_generator,
            steps_per_epoch=train_samples // batch_size,
            epochs=epochs,
            validation_data=validation_generator,
            validation_steps=validation_samples // batch_size)
# Out:
# Epoch 1/10
# 8/9 [=========================>....] - ETA: 0s - loss: 1.3346 - acc: 0.3281Epoch 1/10
# 9/9 [==============================] - 7s 755ms/step - loss: 1.3094 - acc: 0.3403 - val_loss: 1.0281 - val_acc: 0.6250
# Epoch 2/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.9932 - acc: 0.4867Epoch 1/10
# 9/9 [==============================] - 5s 529ms/step - loss: 0.9741 - acc: 0.5039 - val_loss: 0.9122 - val_acc: 0.6875
# Epoch 3/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.8018 - acc: 0.6562Epoch 1/10
# 9/9 [==============================] - 4s 428ms/step - loss: 0.7948 - acc: 0.6389 - val_loss: 0.6139 - val_acc: 0.8333
# Epoch 4/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4894 - acc: 0.7812Epoch 1/10
# 9/9 [==============================] - 3s 387ms/step - loss: 0.4950 - acc: 0.7708 - val_loss: 0.4981 - val_acc: 0.8750
# Epoch 5/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3691 - acc: 0.8359Epoch 1/10
# 9/9 [==============================] - 3s 388ms/step - loss: 0.3740 - acc: 0.8333 - val_loss: 0.2873 - val_acc: 0.9583
# Epoch 6/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2657 - acc: 0.8761Epoch 1/10
# 9/9 [==============================] - 3s 332ms/step - loss: 0.2647 - acc: 0.8837 - val_loss: 0.1808 - val_acc: 1.0000
# Epoch 7/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1264 - acc: 0.9531Epoch 1/10
# 9/9 [==============================] - 4s 425ms/step - loss: 0.1404 - acc: 0.9514 - val_loss: 0.1156 - val_acc: 1.0000
# Epoch 8/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1928 - acc: 0.9297Epoch 1/10
# 9/9 [==============================] - 4s 393ms/step - loss: 0.1814 - acc: 0.9375 - val_loss: 0.1411 - val_acc: 0.9792
# Epoch 9/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1434 - acc: 0.9375Epoch 1/10
# 9/9 [==============================] - 3s 385ms/step - loss: 0.1870 - acc: 0.9306 - val_loss: 0.0819 - val_acc: 1.0000
# Epoch 10/10
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1048 - acc: 0.9646Epoch 1/10
# 9/9 [==============================] - 3s 336ms/step - loss: 0.1279 - acc: 0.9457 - val_loss: 0.1589 - val_acc: 0.9792

# %%
#plotting accuracy chart

history_dict=history.history

loss_values=history_dict['acc']
val_loss_values=history_dict['val_acc']
epochs=range(1,len(loss_values)+1)

line1=plt.plot(epochs,val_loss_values,label='Validation Accuracy')
line2=plt.plot(epochs,loss_values,label='Training Accuracy')

plt.setp(line1,linewidth=2.0,marker='+',markersize=10.0)
plt.setp(line2,linewidth=2.0,marker='4',markersize=10.0)

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
